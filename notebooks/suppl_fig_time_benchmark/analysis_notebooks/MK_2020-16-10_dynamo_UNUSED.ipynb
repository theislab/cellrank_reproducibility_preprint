# %%
import utils.utilities as utilities
import cellrank as cr
import scanpy as sc
import numpy as np

from pathlib import Path

cr.logging.print_versions()
# Out:
# Dynamo custom version (not broken fates): 0.95.1.dev4+bb86e69.dirty
# cellrank==1.0.0-rc.12 scanpy==1.5.1 anndata==0.7.4 numpy==1.19.2 numba==0.51.2 scipy==1.5.2 pandas==1.1.2 scikit-learn==0.23.1 statsmodels==0.11.1 python-igraph==0.8.2 scvelo==0.1.26.dev302+g8f6764f.d20201002 pygam==0.8.0 matplotlib==3.3.0 seaborn==0.10.1

# %%
adata = sc.read(Path.home() / 'server_home/crb_bak/data/merged.h5ad')
del adata.layers['matrix']
del adata.layers['ambiguous']
adata
# Out:
# AnnData object with n_obs × n_vars = 104679 × 22630
#     obs: 'batch'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'spliced', 'unspliced'

# %%
dfs = utilities.get_split(Path.home() / 'server_home/crb_bak/splits')
dfs.keys()
# Out:
# dict_keys([10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000])

# %%
dst_dir = Path.home() / "server_home/analysis/dynamo.pickle"
dst_dir.parent.mkdir(exist_ok=True)
dst_dir
# Out:
# PosixPath('/home/marius.lange/server_home/analysis/dynamo.pickle')

# %%
# this also needs the roots (not used below)
# we 
utilities.benchmark_dynamo(adata, dfs, path=dst_dir,
                           dynamo_roots=Path.home() / "server_home/analysis/gpcca_bwd.pickle")
# Out:
# Subsetting data to `10000`, split `0`.
# Preprocessing and clustering
# Calculating moments
# Calculating dynamics
# Dimnesionality reduction
# Calculating velocities
# calculating transition matrix via pearson kernel with sqrt transform.: 100%|██████████| 9965/9965 [00:33<00:00, 300.16it/s]
# projecting velocity vector to low dimensional embedding...: 100%|██████████| 9965/9965 [00:02<00:00, 4978.75it/s]
# Calculating vector field
# integration with ivp solver:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
# ...
# integration with ivp solver:   0%|          | 0/1 [00:00<?, ?it/s]
#
# integration with ivp solver:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# integration with ivp solver:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# integration with ivp solver:   0%|          | 0/1 [00:00<?, ?it/s]
# Calculating fates
# integration with ivp solver:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# integration with ivp solver:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# ...
